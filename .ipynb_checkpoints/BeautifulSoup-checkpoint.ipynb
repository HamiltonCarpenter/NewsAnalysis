# %%
import requests
import pymongo
page = requests.get("https://www.bostonglobe.com/news/politics/2019/07/11/paul-ryan-says-trump-didn-know-anything-about-government-new-tim-alberta-book/kF73FUHFcRJUGua7nDtzfL/story.html")
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><script type="text/javascript" src="//dz9qn8fh4jznm.cloudfront.net/script.js"></script><title>Paul Ryan says Trump \xe2\x80\x98didn\xe2\x80\x99t know anything about government\xe2\x80\x99 in new Tim Alberta book - The Boston Globe</title><meta name="description" content="\xe2\x80\x98\xe2\x80\x98American Carnage\xe2\x80\x99\xe2\x80\x99 is filled with vivid details and on-the-record quotes from prominent Republican officials and includes an interview with President Trump himself."/><meta name="keywords" content="trump-book"/><meta name="robots" content="noarchive"/><script type="application/javascript"> if ( !(\'scrollingElement\' in document) || !(Element.prototype.matches) || !(window.URLSearchParams) || !(String.prototype.includes) ) { document.write(\'<scr\'+\'ipt type="application/javascript" src="/pf/resources/dist/all-polyfills.js?d=71" defer=""></sc\'+\'ript>\') }  </script><script type="application/javascript">if(!Array.prototype.inclu
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <script src="//dz9qn8fh4jznm.cloudfront.net/script.js" type="text/javascript">
#   </script>
#   <title>
#    Paul Ryan says Trump ‘didn’t know anything about government’ in new Tim Alberta book - The Boston Globe
#   </title>
#   <meta content="‘‘American Carnage’’ is filled with vivid details and on-the-record quotes from prominent Republican officials and includes an interview with President Trump himself." name="description"/>
#   <meta content="trump-book" name="keywords"/>
#   <meta content="noarchive" name="robots"/>
#   <script type="application/javascript">
#    if ( !('scrollingElement' in document) || !(Element.prototype.matches) || !(window.URLSearchParams) || !(String.prototype.includes) ) { document.write('<scr'+'ipt type="application/javascript" src="/pf/resources/dist/all-polyfills.js?d=71" defer=""></sc'+'ript>') }
#   </script>
#   <script type="application/javascript">
# ...

# %%
list(soup.children)
# Out:
# ['html',
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.Tag]

# %%
html = list(soup.children)[1]

# %%
list(html.children)
# Out:
# [<head><script src="//dz9qn8fh4jznm.cloudfront.net/script.js" type="text/javascript"></script><title>Paul Ryan says Trump ‘didn’t know anything about government’ in new Tim Alberta book - The Boston Globe</title><meta content="‘‘American Carnage’’ is filled with vivid details and on-the-record quotes from prominent Republican officials and includes an interview with President Trump himself." name="description"/><meta content="trump-book" name="keywords"/><meta content="noarchive" name="robots"/><script type="application/javascript"> if ( !('scrollingElement' in document) || !(Element.prototype.matches) || !(window.URLSearchParams) || !(String.prototype.includes) ) { document.write('<scr'+'ipt type="application/javascript" src="/pf/resources/dist/all-polyfills.js?d=71" defer=""></sc'+'ript>') }  </script><script type="application/javascript">if(!Array.prototype.includes||!(window.Object && window.Object.assign)||!window.Promise||!window.Symbol||!window.fetch){document.write('<script t
# ...

# %%
html.children

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p class="paragraph | gutter_20_0--mobile margin_vertical_40"><span class="html-render">WASHINGTON — Few people have more power in President Trump’s White House than Madeleine Westerhout, his executive assistant who controls access to the Oval Office, delivers the president’s marker-scribbled messages, sends orders to top military officials, prints emails and articles to show Trump, and seeks to keep a tight grip on his schedule.</span></p>,
#  <p class="paragraph | gutter_20_0--mobile margin_vertical_40"><span class="html-render">But she was not always a staunch supporter of the president. On election night, Westerhout, then a Republican National Committee aide, broke down crying, ‘‘inconsolable’’ over Trump winning the election.</span></p>,
# ...

# %%
[x.get_text() for x in soup.find_all('p')]
# Out:
# ['WASHINGTON — Few people have more power in President Trump’s White House than Madeleine Westerhout, his executive assistant who controls access to the Oval Office, delivers the president’s marker-scribbled messages, sends orders to top military officials, prints emails and articles to show Trump, and seeks to keep a tight grip on his schedule.',
#  'But she was not always a staunch supporter of the president. On election night, Westerhout, then a Republican National Committee aide, broke down crying, ‘‘inconsolable’’ over Trump winning the election.',
#  '‘‘To the amusement of her RNC peers, she was later chosen as the president’s executive assistant and now sits just outside the Oval Office,’’ writes Tim Alberta in ‘‘American Carnage,’’ a copy of which was obtained by The Washington Post ahead of its scheduled release Tuesday.',
#  'Advertisement',
# ...

# %% [markdown]
# soup.find_all('p')]

# %%
soup.find_all('p')
# Out:
# [<p class="paragraph | gutter_20_0--mobile margin_vertical_40"><span class="html-render">WASHINGTON — Few people have more power in President Trump’s White House than Madeleine Westerhout, his executive assistant who controls access to the Oval Office, delivers the president’s marker-scribbled messages, sends orders to top military officials, prints emails and articles to show Trump, and seeks to keep a tight grip on his schedule.</span></p>,
#  <p class="paragraph | gutter_20_0--mobile margin_vertical_40"><span class="html-render">But she was not always a staunch supporter of the president. On election night, Westerhout, then a Republican National Committee aide, broke down crying, ‘‘inconsolable’’ over Trump winning the election.</span></p>,
# ...

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local']

# %%
col = mydb.mydatabase

# %%
col
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase'), 'mydatabase')

# %%
import datetime
post ={'author': 'The Hog',
      'text': 'Bane is big'}

# %%
posts = mydb.posts
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('5d294016bfee71bf20442e42')

# %%
mydb.list_collection_names()
# Out:
# ['posts']

# %%
import pprint

# %%
pprint.pprint(posts.find_one())
# Out:
# {'_id': ObjectId('5d294016bfee71bf20442e42'),
#  'author': 'The Hog',
#  'text': 'Bane is big'}

# %%
pprint.pprint(posts.find_one({'author': 'Bane'}))
# Out:
# None

# %%
bulky_boi = [{'author':'Cuck_Lord_Abdula',
             'text':'naw man i dont like text make it a jpeg trust me ittl work ill kill you'},
             {'author': 'The Hog',
             'title':'The Plane Scene',
             'text':'long live the wreckage brothers'}]

# %%
result = posts.insert_many(bulky_boi)

# %%
pprint.pprint(posts.find_one({'author': "Cuck_Lord_Abdula"}))
# Out:
# {'_id': ObjectId('5d2943e5bfee71bf20442e43'),
#  'author': 'Cuck_Lord_Abdula',
#  'text': 'naw man i dont like text make it a jpeg trust me ittl work ill kill '
#          'you'}

# %%
posts.find()

# %%
for p in posts.find():
    pprint.pprint(p)
# Out:
# {'_id': ObjectId('5d294016bfee71bf20442e42'),
#  'author': 'The Hog',
#  'text': 'Bane is big'}
# {'_id': ObjectId('5d2943e5bfee71bf20442e43'),
#  'author': 'Cuck_Lord_Abdula',
#  'text': 'naw man i dont like text make it a jpeg trust me ittl work ill kill '
#          'you'}
# {'_id': ObjectId('5d2943e5bfee71bf20442e44'),
#  'author': 'The Hog',
#  'text': 'long live the wreckage brothers',
#  'title': 'The Plane Scene'}

# %%
for p in posts.find({'author':'The Hog'}):
    pprint.pprint(p)
# Out:
# {'_id': ObjectId('5d294016bfee71bf20442e42'),
#  'author': 'The Hog',
#  'text': 'Bane is big'}
# {'_id': ObjectId('5d2943e5bfee71bf20442e44'),
#  'author': 'The Hog',
#  'text': 'long live the wreckage brothers',
#  'title': 'The Plane Scene'}

# %%
import mechanize
import urllib2 
import cookielib

cj = cookielib.CookieJar()
br = mechanize.Browser()
br.set_cookiejar(cj)
br.open("https://www.nytimes.com/")

br.select_form(nr=0)
br.form['username'] = 'Hammyman007@gmail.com'
br.form['password'] = 'hogNYT1.'
br.submit()

print(br.response().read())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-9530db00ae4b> in <module>
#       1 import mechanize
# ----> 2 import urllib2
#       3 import cookielib
#       4
#       5 cj = cookielib.CookieJar()
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import mechanicalsoup

# %%
browser = mechanicalsoup.StatefulBrowser()

# %%
browser.open("http://httpbin.org/")
# Out:
# <Response [200]>

# %%
browser.get_url()
# Out:
# 'http://httpbin.org/'

# %%
browser.get_current_page()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>httpbin.org</title>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,600,700" rel="stylesheet"/>
# <link href="/flasgger_static/swagger-ui.css" rel="stylesheet" type="text/css"/>
# <link href="/static/favicon.ico" rel="icon" sizes="64x64 32x32 16x16" type="image/png"/>
# <style>
#         html {
#             box-sizing: border-box;
#             overflow: -moz-scrollbars-vertical;
#             overflow-y: scroll;
#         }
#
#         *,
#         *:before,
#         *:after {
#             box-sizing: inherit;
#         }
#
#         body {
#             margin: 0;
#             background: #fafafa;
#         }
#     </style>
# </head>
# <body>
# <a aria-label="View source on Github" class="github-corner" href="https://github.com/requests/httpbin">
# ...

# %%
from __future__ import print_function
import argparse
import mechanicalsoup
from getpass import getpass


parser = argparse.ArgumentParser(description="Login to GitHub.")
#parser.add_argument("username")
#args = parser.parse_args()
#args.password = getpass("Please enter your GitHub password: ")

browser = mechanicalsoup.StatefulBrowser(
    soup_config={'features': 'lxml'},
    raise_on_404=True,
    user_agent='MyBot/0.1: mysite.example.com/bot_info',
)

# %%
# Uncomment for a more verbose output:
# browser.set_verbose(2)

browser.open("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")
#browser.follow_link("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")
browser.select_form('login-form')
browser["login"] = "Hammyman007@gmail.com"  #args.username
browser["password"] = "hogNYT1"  #args.password
resp = browser.submit_selected()
browser.post
browser.
# Uncomment to launch a web browser on the current page:
# browser.launch_browser()
#<a href="https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi" 
#class="css-1kj7lfb"><button class="css-1bnxwmn ez4a0qj0" data-testid="login-button">Log In</button></a>
# Out:
# ---------------------------------------------------------------------------
# LinkNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-7bfef3160ebc> in <module>
#       4 browser.open("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")
#       5 #browser.follow_link("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")
# ----> 6 browser.select_form('login-form')
#       7 browser["login"] = "Hammyman007@gmail.com"  #args.username
#       8 browser["password"] = "hogNYT1"  #args.password
#
# ~/.local/lib/python3.6/site-packages/mechanicalsoup/stateful_browser.py in select_form(self, selector, nr)
#     205                     print('select_form failed for', selector)
#     206                     self.launch_browser()
# --> 207                 raise LinkNotFoundError()
#     208             self.__state.form = Form(found_forms[-1])
#     209
#
# LinkNotFoundError:

# %%
# verify we are now logged in
page = browser.get_current_page()
messages = page.find("div", class_="flash-messages")
if messages:
    print(messages.text)
assert page.select(".logout-form")

print(page.title.text)

# verify we remain logged in (thanks to cookies) as we browse the rest of
# the site
page3 = browser.open("https://github.com/MechanicalSoup/MechanicalSoup")
assert page3.soup.select(".logout-form")

# %%
browser.open("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")
#browser.follow_link("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")
browser.select_form('login-form')
browser["login"] = "Hammyman007@gmail.com"  #args.username
browser["password"] = "hogNYT1"  #args.password

# %%
URL = "https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi"
LOGIN = "Hammyman007@gmail.com"
PASSWORD = "hogNYT1"
#TWITTER_NAME = “twittername” # without @

# Create a browser object
browser = mechanicalsoup.Browser()

# request Twitter login page
login_page = browser.get(URL)

# we grab the login form
login_form = login_page.soup.find("form", {"class":"css-ujhzpp-form-Form"})

# find login and password inputs
login_form.find("input", {"name": "session[Email Address]"})["value"] = LOGIN
login_form.find("input", {"name": "session[Password]"})["value"] = PASSWORD

# submit form
response = browser.submit(login_form, login_page.url)

# verify we are now logged in ( get username in webpage )
user = response.soup.find("a", class_="u-linkComplex").text

#if TWITTER_NAME in user:
#    print(“You’re connected as “ + TWITTER_NAME)
#else:
#    print(“Not connected”)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-795d63181e9b> in <module>
#      14
#      15 # find login and password inputs
# ---> 16 login_form.find("input", {"name": "session[Email Address]"})["value"] = LOGIN
#      17 login_form.find("input", {"name": "session[Password]"})["value"] = PASSWORD
#      18
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
a = browser.get("https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi")

# %%
a.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n    <head>\n        <title>The New York Times</title>\n\n        <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n        <meta name="sourceApp" content="nyt-lire" />\n        <meta name="viewport" content="initial-scale=1, maximum-scale=1" />\n\n        <style>\n            @font-face {\n                font-family: nyt-franklin;\n                src: url(//typeface.nyt.com/fonts/nyt-franklin-300-normal.woff)\n                    format(\'woff\');\n                font-style: normal;\n                font-weight: 300;\n            }\n\n            @font-face {\n                font-family: nyt-franklin;\n                src: url(//typeface.nyt.com/fonts/nyt-franklin-500-normal.woff)\n                    format(\'woff\');\n                font-style: normal;\n                font-weight: 500;\n            }\n\n            html,\n            body {\n                height: 100%;\n            }\n\n            body {\n           
# ...

# %%
raw file:
datetime
site
url 
rawtext

# %%
import requests 
from requests.auth import HTTPBasicAuth
requests.get('https://myaccount.nytimes.com/auth/login?response_type=cookie&amp;client_id=vi', auth=HTTPBasicAuth('user', 'pass'))
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
links = soup.findAll("a")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-e124e8959d2b> in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 links = soup.findAll("a")
#
# NameError: name 'soup' is not defined

# %%
import urllib.request, urllib.response, cookiejar
from http.cookiejar import CookieJar
username = "Hammyman007@gmail.com"
password = "hogNYT1"

cj     = CookieJar()
with urllib.request.urlopen("https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi&redirect_uri=https%3A%2F%2Fwww.nytimes.com%2F") as url:
    s = url.read()
    # I'm guessing this would output the html source code ?
 #   print(s)
#login_data = urllib.urlencode({'Email Address' : username, 'Password' : password})
#opener.open('http://www.example.com/login.php', login_data)
#resp = opener.open('http://www.example.com/hiddenpage.php')
#print (resp.read())

#auth_handler = urllib.request.HTTPBasicAuthHandler(p)
#opener = urllib.request.build_opener(auth_handler)

#urllib.request.install_opener(opener)

# %%
import urllib.request, urllib.response, cookiejar
from http.cookiejar import CookieJar
username = "Hammyman007@gmail.com"
password = "hogNYT1"
top_level_url = "https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi&redirect_uri=https%3A%2F%2Fwww.nytimes.com%2F"

# create an authorization handler
p = urllib.request.HTTPPasswordMgrWithDefaultRealm()
p.add_password(None, top_level_url, username, password);

auth_handler = urllib.request.HTTPBasicAuthHandler(p)
opener = urllib.request.build_opener(auth_handler)

urllib.request.install_opener(opener)

DATA = b'{"data": { "foo": "bar", "timestamp": 1466593290 }}'
try:
    req = urllib.request.Request("https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi&redirect_uri=https%3A%2F%2Fwww.nytimes.com%2F", data=DATA, headers={'Content-Type': 'application/json'})    
    result = opener.open(req)
    messages = result.read()
    print (messages)
except IOError as e:
    print (e)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n    <head>\n        <title>The New York Times</title>\n\n        <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n        <meta name="sourceApp" content="nyt-lire" />\n        <meta name="viewport" content="initial-scale=1, maximum-scale=1" />\n\n        <style>\n            @font-face {\n                font-family: nyt-franklin;\n                src: url(//typeface.nyt.com/fonts/nyt-franklin-300-normal.woff)\n                    format(\'woff\');\n                font-style: normal;\n                font-weight: 300;\n            }\n\n            @font-face {\n                font-family: nyt-franklin;\n                src: url(//typeface.nyt.com/fonts/nyt-franklin-500-normal.woff)\n                    format(\'woff\');\n                font-style: normal;\n                font-weight: 500;\n            }\n\n            html,\n            body {\n                height: 100%;\n            }\n\n            body {\n          
# ...

# %%
import sqlite3
import cookiejar

def get_cookies(cj, ff_cookies):
    con = sqlite3.connect(ff_cookies)
    cur = con.cursor()
    cur.execute("SELECT host, path, isSecure, expiry, name, value FROM moz_cookies")
    for item in cur.fetchall():
        c = cookielib.Cookie(0, item[4], item[5],
            None, False,
            item[0], item[0].startswith('.'), item[0].startswith('.'),
            item[1], False,
            item[2],
            item[3], item[3]=="",
            None, None, {})
        print(c)
        cj.set_cookie(c)
        
    
    
#get_cookies(,"/home/hog/.mozilla/firefox/opn3ryh1.default/cookies.sqlite")

# %%
import requests, sys

cj = CookieJar()
ff_cookies = "/home/hog/.mozilla/firefox/opn3ryh1.default/cookies.sqlite"#sys.argv[1] #pass path to the cookies.sqlite as an argument to the script
get_cookies(cj, ff_cookies)
s = requests.Session()
s.cookies = cj
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-71-ce79826448cf> in <module>
#       3 cj = CookieJar()
#       4 ff_cookies = "/home/hog/.mozilla/firefox/opn3ryh1.default/cookies.sqlite"#sys.argv[1] #pass path to the cookies.sqlite as an argument to the script
# ----> 5 get_cookies(cj, ff_cookies)
#       6 s = requests.Session()
#       7 s.cookies = cj
#
# <ipython-input-70-476d9fd467a8> in get_cookies(cj, ff_cookies)
#       5     con = sqlite3.connect(ff_cookies)
#       6     cur = con.cursor()
# ----> 7     cur.execute("SELECT host, path, isSecure, expiry, name, value FROM moz_cookies")
#       8     for item in cur.fetchall():
#       9         c = cookielib.Cookie(0, item[4], item[5],
#
# OperationalError: database is locked

# %%
import pickle

# %%
import urllib3

# %%
urllib3.

# %%
import urllib3
import re
import browsercookie
from bs4 import BeautifulSoup
import bs4



url = "https://www.nytimes.com/2019/07/15/opinion/trump-aoc-omar-pelosi.html"
url = "https://www.nytimes.com/"
url = "https://www.nytimes.com/2019/07/15/opinion/donald-trump-tweet.html"
http = urllib3.PoolManager()

response = http.request('GET', url)
soup = BeautifulSoup(response.data)
#print(soup.prettify())
soup.find_all('p')
# Out:
# [<p>Advertisement</p>,
#  <p>Supported by</p>,
#  <p class="css-1ifw933 e1wiw3jv0">The president distracts with outrage. If only Republicans would supply some of it.</p>,
#  <p class="css-16vrk19 e1jsehar1" itemprop="author" itemscope="" itemtype="http://schema.org/Person">By<!-- --> <a class="css-1riqqik e1jsehar0" href="https://www.nytimes.com/interactive/opinion/editorialboard.html"><span class="css-1baulvz" itemprop="name">The Editorial Board</span></a></p>,
#  <p class="css-ri4qrz e1wtpvyy1">The editorial board represents the opinions of the board, its editor and the publisher. It is separate from the newsroom and the Op-Ed section.</p>,
#  <p class="css-exrw3m evys1bk0">President Trump is at it again.</p>,
# ...

# %%
def get_only_text(elem):
    for item in elem:
        if isinstance(item,bs4.element.NavigableString):
            yield item

# %%
[x for x in get_only_text(soup)]
# Out:
# ['html']

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="story" itemid="https://www.nytimes.com/2019/07/15/opinion/donald-trump-tweet.html" itemscope="" itemtype="http://schema.org/NewsArticle" lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title data-rh="true">Opinion | How Do You Not Give Donald Trump What He Wants? - The New York Times</title>
# ...

# %%
html = "<foo>Something something <bar> blah blah</bar> something <bar2>GONE!</bar2> else</foo>"
html = response.data
def get_only_text(elem):
    r_str = []
    for a in elem:
        for item in a.children:
            if isinstance(item,bs4.element.NavigableString):
                r_str.append(item)
    return r_str
#print (''.join(get_only_text(BeautifulSoup(html).find_all('p')[7])))

# %%
[x for x in get_only_text(BeautifulSoup(html).find_all('p'))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-d765cf2f4f48> in <module>
# ----> 1 [x for x in get_only_text(BeautifulSoup(html).find_all('p'))]
#
# <ipython-input-26-d765cf2f4f48> in <listcomp>(.0)
# ----> 1 [x for x in get_only_text(BeautifulSoup(html).find_all('p'))]
#
# <ipython-input-25-126f0a6f5ede> in get_only_text(elem)
#       2 html = response.data
#       3 def get_only_text(elem):
# ----> 4     for item in elem.children:
#       5         if isinstance(item,bs4.element.NavigableString):
#       6             yield item
#
# ~/.local/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# ...

# %%
for 
''.join(get_only_text(BeautifulSoup(html).find_all('p')[x])))
# Out:
# The president distracts with outrage. If only Republicans would supply some of it.

# %%
get_only_text(BeautifulSoup(html).find_all('p'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-3333711bfb99> in <module>
# ----> 1 get_only_text(BeautifulSoup(html).find_all('p'))
#
# <ipython-input-36-cfdd6a7d08b3> in get_only_text(elem)
#       3 def get_only_text(elem):
#       4     r_str = []
# ----> 5     for item in elem.children:
#       6         if isinstance(item,bs4.element.NavigableString):
#       7             r_str.append(item)
#
# ~/.local/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# ...

# %%
get_only_text(BeautifulSoup(html).find_all('p'))
# Out:
# ['Advertisement',
#  'Supported by',
#  'The president distracts with outrage. If only Republicans would supply some of it.',
#  'By',
#  ' ',
#  ' ',
#  'The editorial board represents the opinions of the board, its editor and the publisher. It is separate from the newsroom and the Op-Ed section.',
#  'President Trump is at it again.',
#  'The president’s ',
#  ' on Sunday, instructing four Democratic congresswomen of color — Representatives Ilhan Omar of Minnesota, Alexandria Ocasio-Cortez of New York, Ayanna Pressley of Massachusetts and Rashida Tlaib of Michigan — to “go back” to their home countries, was as wearisome as it was repellent. ',
#  'Distraction by outrage is one of Mr. Trump’s favorite tactics. Whenever things aren’t going as he wants — for instance, when his crusade to put a citizenship question on the 2020 census ',
#  ', or when the dramatic wave of immigration raids he promised his most loyal supporters ',
#  ' ',
#  'does not materialize',
#  ' ',
# ...

# %%
soup = BeautifulSoup(response.data)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="story" itemid="https://www.nytimes.com/2019/07/15/opinion/donald-trump-tweet.html" itemscope="" itemtype="http://schema.org/NewsArticle" lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <title data-rh="true">
#    Opinion | How Do You Not Give Donald Trump What He Wants? - The New York Times
#   </title>
#   <meta content="en-US" data-rh="true" itemprop="inLanguage"/>
#   <meta content="2019-07-16T00:40:36.000Z" data-rh="true" itemprop="datePublished dateCreated" property="article:published"/>
#   <meta content="2019-07-16T22:31:17.233Z" data-rh="true" itemprop="dateModified" property="article:modified"/>
#   <meta content="en" data-rh="true" http-equiv="Content-Language"/>
#   <meta content="noarchive" data-rh="true" name="robots"/>
#   <meta content="100000006612714" data-rh="true" itemprop="identifier" name="articleid"/>
# ...
